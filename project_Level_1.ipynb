# %% [markdown]
# <a href="https://colab.research.google.com/github/Witcape/project_level_1/blob/main/project_Level_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
data_full = pd.read_csv('/content/gdrive/MyDrive/House_price/Housing.csv')

# %%
data_full.head(545)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data_full["guestroom"] = data_full["guestroom"].replace({"yes": 1, "no": 0})
data_full["mainroad"] = data_full["mainroad"].replace({"yes": 1, "no": 0})
data_full["basement"] = data_full["basement"].replace({"yes": 1, "no": 0})
data_full["hotwaterheating"] = data_full["hotwaterheating"].replace({"yes": 1, "no": 0})
data_full["airconditioning"] = data_full["airconditioning"].replace({"yes": 1, "no": 0})
data_full["prefarea"] = data_full["prefarea"].replace({"yes": 1, "no": 0})
data_full["furnishingstatus"] = data_full["furnishingstatus"].replace({"furnished": 1, "semi-furnished": 0.8, "unfurnished":0})

# %%
data_full
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.utils import shuffle

shu_data_full = shuffle(data_full, random_state=42)
data_full
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
data=  shu_data_full.iloc[:, 1:13]
target=  shu_data_full.iloc[:, [0]]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

data_scaler = StandardScaler()
target_scaler = MinMaxScaler()

scaled_data = data_scaler.fit_transform(data)
scaled_target = target_scaler.fit_transform(target)

data = scaled_data
target = scaled_target

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=50)

# %%
X_train.shape
# Out:
# (490, 12)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.linear_model import LinearRegression
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.activations import linear,relu,sigmoid

# %%
model = Sequential(
    [
        tf.keras.Input(shape = (12,)),
        Dense(30, activation = 'relu'),
        Dense(15, activation = 'relu'),
        Dense(1, activation = 'sigmoid')
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_47 (Dense)            (None, 30)                390
#
#  dense_48 (Dense)            (None, 15)                465
#
#  dense_49 (Dense)            (None, 1)                 16
#
# ...
# Total params: 871
# Trainable params: 871
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(),
    loss = 'mean_squared_error',
)

# %%
history = model.fit(
    X_train, y_train,
    epochs = 40
)
# Out:
# Epoch 1/40
# 14/14 [==============================] - 1s 2ms/step - loss: 0.0774
# Epoch 2/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0540
# Epoch 3/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0390
# Epoch 4/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 5/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 6/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0158
# Epoch 7/40
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0131
# Epoch 8/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 9/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0102
# Epoch 10/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 11/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0088
# Epoch 12/40
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0083
# ...

# %%
loss = history.history['loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss
# Out:
# [0.07735958695411682,
#  0.05401173606514931,
#  0.03897196799516678,
#  0.027984680607914925,
#  0.02044103853404522,
#  0.015819912776350975,
#  0.013121251948177814,
#  0.011343619786202908,
#  0.01021340861916542,
#  0.009427851065993309,
#  0.008805327117443085,
#  0.008339597843587399,
#  0.007985674776136875,
#  0.007713428698480129,
#  0.007395198568701744,
#  0.0072468058206140995,
#  0.006980595178902149,
#  0.006804257165640593,
#  0.006647217087447643,
#  0.006551325786858797,
#  0.006433709058910608,
#  0.006332464050501585,
#  0.006230573169887066,
#  0.006165638566017151,
#  0.006023782305419445,
#  0.006025942042469978,
#  0.005859441589564085,
#  0.005808610934764147,
#  0.005743220914155245,
#  0.005683914292603731,
#  0.005620860494673252,
#  0.00556138064712286,
#  0.005514693446457386,
#  0.005459926091134548,
#  0.005382044706493616,
#  0.005348681937903166,
#  0.005320090334862471,
#  0.005233012139797211,
#  0.005207532085478306,
#  0.005155451595783234]

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
mse = np.mean((y_test - predictions.flatten()) ** 2)
print("Mean Squared Error (MSE) on testing data:", mse)
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
r2
# Out:
# Mean Squared Error (MSE) on testing data: 0.05562851539118461
# 0.6414112955467925

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
Y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, Y_pred)

# %%
mse
# Out:
# 0.00985031774625132

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, Y_pred)
r2
# Out:
# 0.6746908997629489
